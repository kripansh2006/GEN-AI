# %% [markdown]
# <a href="https://colab.research.google.com/github/kripansh2006/GEN-AI/blob/main/generative_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Import library
#2. Import data(from google drive to goggle colab)
#3. Data analysis i.Find the information of data
                 #ii.Find the null value
                 #iii.How does the data look mathematically
#4.Model prediction

# %%
# import library
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/Data/placement (1).csv")

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/drive/MyDrive/Data/placement (1).csv")
#find independent and dependent feature
x = df.iloc[:, 0]
y = df.iloc[:, 1]
x
# Out:
# 0      6.89
# 1      5.12
# 2      7.82
# 3      7.42
# 4      6.94
#        ...
# 195    6.93
# 196    5.89
# 197    7.21
# 198    7.63
# 199    6.22
# Name: cgpa, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
x_train
# Out:
# 79     7.18
# 197    7.21
# 38     8.62
# 24     6.53
# 122    5.12
#        ...
# 106    6.13
# 14     7.73
# 92     7.90
# 179    7.14
# 102    5.13
# Name: cgpa, Length: 160, dtype: float64

# %%
#training the model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train.values.reshape(-1,1), y_train)
# Out:
# LinearRegression()

# %%
#cofficient
m = model.coef_
print(m[0])
# Out:
# 0.5742564727019197

# %%
#intercept
b = model.intercept_
print(b)
# Out:
# -1.0270069374542108

# %%
cgpa = 9.5
package = m*cgpa+b
print(package)
# Out:
# [4.42842955]

# %%
# testing the model
y_pred = model.predict(x_test.values.reshape(-1,1))
y_pred,y_test
# Out:
# (array([2.78031348, 3.13635249, 3.1995207 , 2.38981908, 3.52684689,
#         3.76803461, 3.16506531, 2.54486832, 3.17655044, 3.4923915 ,
#         1.90744364, 2.34962112, 3.6876387 , 2.75734322, 3.47516381,
#         3.04447145, 2.32665086, 3.20526327, 2.17734418, 3.314372  ,
#         2.45298729, 2.90090734, 3.32011456, 2.87219451, 3.33734226,
#         2.19457187, 1.41932564, 2.7114027 , 3.18229301, 2.32665086,
#         3.74506435, 2.95833298, 3.68189614, 2.97556068, 2.59080884,
#         3.34882738, 2.47595755, 3.07318428, 4.17575671, 2.95833298]),
#  95     2.79
#  15     3.23
#  30     3.26
#  158    3.04
#  128    3.34
#  115    4.21
#  69     2.94
#  170    2.87
#  174    2.99
#  45     3.58
#  66     1.63
#  182    2.08
#  165    4.08
#  78     2.21
#  186    3.47
#  177    3.64
#  56     2.74
#  152    3.08
#  82     2.17
#  68     2.99
#  124    2.31
#  16     2.35
#  148    3.40
#  93     3.08
#  65     3.81
#  60     2.19
#  84     1.53
#  67     2.89
#  125    3.16
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df["cgpa"],df["package"])
plt.plot(x_test, y_pred, color="red")
plt.xlabel("CGPA")
plt.xlabel("Package")
plt.show()
